# %% [markdown]
# # Locations
#
# Notebook mirror of the Streamlit Locations tab.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

ROOT = Path('..').resolve()
CSV_DIR = ROOT / 'results' / 'csv'
FIG_DIR = ROOT / 'results' / 'figures'
DOMAIN = 'IT'
domain_slug = DOMAIN.lower().replace(' ', '_')

# %%
pd.read_csv(CSV_DIR / f'{domain_slug}_locations.csv')

# %%
pd.read_csv(CSV_DIR / 'all_domains_locations.csv')

# %%
path = FIG_DIR / 'advanced_location_coverage.png'
if path.exists():
    display(Image(filename=str(path)))
