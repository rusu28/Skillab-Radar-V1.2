# %% [markdown]
# # Methodology
#
# Notebook mirror of the Streamlit Methodology tab.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path('..').resolve()
CSV_DIR = ROOT / 'results' / 'csv'
PROV_DIR = ROOT / 'results' / 'provenance'

# %% [markdown]
# All labour-market data comes from the SKILLAB Tracker API. ESCO/ISCO files are metadata only. The key idea is to combine demand, supply, trend, training response, and candidate fit into one reproducible workflow.

# %%
pd.read_csv(CSV_DIR / 'methodology_table.csv')

# %%
print('Pipeline provenance is stored per domain under results/provenance/.')
print('Core formulas are stored in results/csv/methodology_table.csv.')

# %%
sorted(path.name for path in CSV_DIR.glob('*.csv'))
