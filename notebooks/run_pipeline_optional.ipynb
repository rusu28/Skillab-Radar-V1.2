# %% [markdown]
# # Optional live API refresh
#
# Run this notebook only if you want to refresh the generated CSV/PNG outputs from the SKILLAB Tracker API. It uses the same pipeline, cache, `.env`, and `config.yaml` as the Streamlit dashboard.

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path('..').resolve()
ROOT
# Out:
# WindowsPath('D:/letmecookguys')

# %%
subprocess.run([sys.executable, '-m', 'src.pipeline', '--config', 'config.yaml'], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['C:\\Users\\NITROPC\\AppData\\Local\\Microsoft\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\python.exe', '-m', 'src.pipeline', '--config', 'config.yaml'], returncode=0)
